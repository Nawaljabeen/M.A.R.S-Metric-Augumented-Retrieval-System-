# %% [markdown]
# <a href="https://colab.research.google.com/github/Nawaljabeen/M.A.R.S-Metric-Augumented-Retrieval-System-/blob/main/MARS_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -q google-generativeai -y
# !pip install -q -U google-genai
# Out:
# WARNING: Skipping google-generativeai as it is not installed.

# %%
from google import genai
from google.colab import userdata

# 1. Initialize the modern Client
client = genai.Client(api_key=userdata.get('Gemini_API_Key'))

# 2. Use 'gemini-2.5-flash' (The current Free Tier standard)
try:
    response = client.models.generate_content(
        model='gemini-2.5-flash',
        contents="System Check: Are you ready to generate Blender Python code?"
    )
    print(f"Assistant: {response.text}")
except Exception as e:
    print(f"❌ Connection Failed. Technical Details: {e}")
# Out:
# Assistant: Yes, I am ready. Please provide your request for Blender Python code.
